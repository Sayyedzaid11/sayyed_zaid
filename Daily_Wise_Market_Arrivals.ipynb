# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayyedzaid11/sayyed_zaid/blob/main/Daily_Wise_Market_Arrivals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_html('/content/DailyWiseMarketArrivals.html')[-1]
df
# Out:
#              Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0     01/Jan/2005  BANGALORE        6823                  440
# 1     03/Jan/2005  BANGALORE        5046                  400
# 2     05/Jan/2005  BANGALORE        6413                  420
# 3     06/Jan/2005  BANGALORE        7496                  440
# 4     07/Jan/2005  BANGALORE        9625                  410
# ...           ...        ...         ...                  ...
# 4184  08/Jul/2022  BANGALORE       10550                 2600
# 4185  11/Jul/2022  BANGALORE       15870                 2600
# 4186  14/Sep/2022  BANGALORE        9220                 1600
# 4187  17/Sep/2022  BANGALORE       13200                 1600
# 4188          NaN      Total    41438323             955(Avg)
#
#      Price Maximum (Rs/q) Modal Price (Rs/q)
# 0                     580                510
# 1                     560                500
# 2                     560                500
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4189 entries, 0 to 4188
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  4188 non-null   object
#  1   Market                4189 non-null   object
#  2   Arrival(q)            4189 non-null   int64
#  3   Price Minimum (Rs/q)  4189 non-null   object
#  4   Price Maximum (Rs/q)  4189 non-null   object
#  5   Modal Price (Rs/q)    4189 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 196.5+ KB

# %%
df.shape
# Out:
# (4189, 6)

# %%
df.isnull().sum()
# Out:
# Date                    1
# Market                  0
# Arrival(q)              0
# Price Minimum (Rs/q)    0
# Price Maximum (Rs/q)    0
# Modal Price (Rs/q)      0
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#              Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0     01/Jan/2005  BANGALORE        6823                  440
# 1     03/Jan/2005  BANGALORE        5046                  400
# 2     05/Jan/2005  BANGALORE        6413                  420
# 3     06/Jan/2005  BANGALORE        7496                  440
# 4     07/Jan/2005  BANGALORE        9625                  410
# ...           ...        ...         ...                  ...
# 4183  04/Jun/2022  BANGALORE        9670                 2400
# 4184  08/Jul/2022  BANGALORE       10550                 2600
# 4185  11/Jul/2022  BANGALORE       15870                 2600
# 4186  14/Sep/2022  BANGALORE        9220                 1600
# 4187  17/Sep/2022  BANGALORE       13200                 1600
#
#      Price Maximum (Rs/q) Modal Price (Rs/q)
# 0                     580                510
# 1                     560                500
# 2                     560                500
# ...

# %%
df.isnull().sum()
# Out:
# Date                    0
# Market                  0
# Arrival(q)              0
# Price Minimum (Rs/q)    0
# Price Maximum (Rs/q)    0
# Modal Price (Rs/q)      0
# dtype: int64

# %%
df = df.rename(columns = {'Modal Price (Rs/q)':'y','Date':'ds'})
df
# Out:
#                ds     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0     01/Jan/2005  BANGALORE        6823                  440
# 1     03/Jan/2005  BANGALORE        5046                  400
# 2     05/Jan/2005  BANGALORE        6413                  420
# 3     06/Jan/2005  BANGALORE        7496                  440
# 4     07/Jan/2005  BANGALORE        9625                  410
# ...           ...        ...         ...                  ...
# 4183  04/Jun/2022  BANGALORE        9670                 2400
# 4184  08/Jul/2022  BANGALORE       10550                 2600
# 4185  11/Jul/2022  BANGALORE       15870                 2600
# 4186  14/Sep/2022  BANGALORE        9220                 1600
# 4187  17/Sep/2022  BANGALORE       13200                 1600
#
#      Price Maximum (Rs/q)     y
# 0                     580   510
# 1                     560   500
# 2                     560   500
# 3                     550   500
# 4                     460   425
# ...

# %%
df_new = df[['ds','y']]
df_new
# Out:
#                ds     y
# 0     01/Jan/2005   510
# 1     03/Jan/2005   500
# 2     05/Jan/2005   500
# 3     06/Jan/2005   500
# 4     07/Jan/2005   425
# ...           ...   ...
# 4183  04/Jun/2022  2400
# 4184  08/Jul/2022  2700
# 4185  11/Jul/2022  2700
# 4186  14/Sep/2022  1800
# 4187  17/Sep/2022  1800
#
# [4188 rows x 2 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4188 entries, 0 to 4187
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4188 non-null   object
#  1   y       4188 non-null   object
# dtypes: object(2)
# memory usage: 98.2+ KB

# %%
df_new['ds'] = pd.to_datetime(df_new['ds'])
df_new['y'] = df_new['y'].astype(int)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4188 entries, 0 to 4187
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4188 non-null   datetime64[ns]
#  1   y       4188 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 98.2 KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (25,5)) 
plt.scatter(df_new['ds'],df_new['y'])

# %%
import prophet
op = prophet.Prophet()

# %%
op.fit(df_new)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmplg2osjqn/h2qqpujj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmplg2osjqn/vc1c77zu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1427', 'data', 'file=/tmp/tmplg2osjqn/h2qqpujj.json', 'init=/tmp/tmplg2osjqn/vc1c77zu.json', 'output', 'file=/tmp/tmplg2osjqn/prophet_modelv8ab1x6p/prophet_model-20221010130913.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:09:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:09:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast = op.make_future_dataframe(periods = 700,freq = 'D')
forecast = op.predict(forecast)

# %%
op.plot(forecast,xlabel = 'Date',ylabel = 'Potato Prices/q')
#black dots/points - real values of potato prices from 2005 to 2022
#Light blue shade - It is the minimum and maximum value as predicted by our model
#dark blue line - Best fit line
