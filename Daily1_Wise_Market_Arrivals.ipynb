# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayyedzaid11/sayyed_zaid/blob/main/Daily1_Wise_Market_Arrivals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_html('/content/DailyWiseMarketArrivals.html')[-1]
df
# Out:
#              Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0     01/Jan/2005  BANGALORE        6823                  440
# 1     03/Jan/2005  BANGALORE        5046                  400
# 2     05/Jan/2005  BANGALORE        6413                  420
# 3     06/Jan/2005  BANGALORE        7496                  440
# 4     07/Jan/2005  BANGALORE        9625                  410
# ...           ...        ...         ...                  ...
# 4182  31/May/2022  BANGALORE        7530                 2000
# 4183  04/Jun/2022  BANGALORE        9670                 2400
# 4184  08/Jul/2022  BANGALORE       10550                 2600
# 4185  11/Jul/2022  BANGALORE       15870                 2600
# 4186          NaN      Total    41415903             954(Avg)
#
#      Price Maximum (Rs/q) Modal Price (Rs/q)
# 0                     580                510
# 1                     560                500
# 2                     560                500
# 3                     550                500
# 4                     460                425
# ...                   ...                ...
# 4182                 2600               2300
# 4183                 2800               2400
# 4184                 2800               2700
# 4185                 2800               2700
# 4186            1407(Avg)          1189(Avg)
#
# [4187 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4187 entries, 0 to 4186
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  4186 non-null   object
#  1   Market                4187 non-null   object
#  2   Arrival(q)            4187 non-null   int64
#  3   Price Minimum (Rs/q)  4187 non-null   object
#  4   Price Maximum (Rs/q)  4187 non-null   object
#  5   Modal Price (Rs/q)    4187 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 196.4+ KB

# %%
df.isnull().sum()
# Out:
# Date                    1
# Market                  0
# Arrival(q)              0
# Price Minimum (Rs/q)    0
# Price Maximum (Rs/q)    0
# Modal Price (Rs/q)      0
# dtype: int64

# %%
df.shape
# Out:
# (4187, 6)

# %%
df.size
# Out:
# 25122

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4186 entries, 0 to 4185
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  4186 non-null   object
#  1   Market                4186 non-null   object
#  2   Arrival(q)            4186 non-null   int64
#  3   Price Minimum (Rs/q)  4186 non-null   object
#  4   Price Maximum (Rs/q)  4186 non-null   object
#  5   Modal Price (Rs/q)    4186 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 228.9+ KB

# %%
df.isnull().sum()
# Out:
# Date                    0
# Market                  0
# Arrival(q)              0
# Price Minimum (Rs/q)    0
# Price Maximum (Rs/q)    0
# Modal Price (Rs/q)      0
# dtype: int64

# %%
df.rename(columns = {'Modal Price (Rs/q)':'y','Date':'ds'},inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#                ds     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0     01/Jan/2005  BANGALORE        6823                  440
# 1     03/Jan/2005  BANGALORE        5046                  400
# 2     05/Jan/2005  BANGALORE        6413                  420
# 3     06/Jan/2005  BANGALORE        7496                  440
# 4     07/Jan/2005  BANGALORE        9625                  410
# ...           ...        ...         ...                  ...
# 4181  22/Feb/2022  BANGALORE        7180                 1600
# 4182  31/May/2022  BANGALORE        7530                 2000
# 4183  04/Jun/2022  BANGALORE        9670                 2400
# 4184  08/Jul/2022  BANGALORE       10550                 2600
# 4185  11/Jul/2022  BANGALORE       15870                 2600
#
#      Price Maximum (Rs/q)     y
# 0                     580   510
# 1                     560   500
# 2                     560   500
# 3                     550   500
# 4                     460   425
# ...                   ...   ...
# 4181                 2000  1800
# 4182                 2600  2300
# 4183                 2800  2400
# 4184                 2800  2700
# 4185                 2800  2700
#
# [4186 rows x 6 columns]

# %%
df_new = df[['ds','y']]
df_new
# Out:
#                ds     y
# 0     01/Jan/2005   510
# 1     03/Jan/2005   500
# 2     05/Jan/2005   500
# 3     06/Jan/2005   500
# 4     07/Jan/2005   425
# ...           ...   ...
# 4181  22/Feb/2022  1800
# 4182  31/May/2022  2300
# 4183  04/Jun/2022  2400
# 4184  08/Jul/2022  2700
# 4185  11/Jul/2022  2700
#
# [4186 rows x 2 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4186 entries, 0 to 4185
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4186 non-null   object
#  1   y       4186 non-null   object
# dtypes: object(2)
# memory usage: 98.1+ KB

# %%
df_new['ds'] = pd.to_datetime(df_new['ds'])
df_new['y'] = df_new['y'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4186 entries, 0 to 4185
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4186 non-null   datetime64[ns]
#  1   y       4186 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 98.1 KB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (25,5))
plt.scatter(df_new['ds'],df_new['y'])

# %%
import prophet
op = prophet.Prophet()
op.fit(df_new)
# Out:
# 15:33:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:33:07 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast = op.make_future_dataframe(periods = 365,freq = 'D')
forecast = op.predict(forecast)

# %%
op.plot(forecast,xlabel = 'Date',ylabel = 'Potato Prices')
